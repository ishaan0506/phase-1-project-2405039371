# %% [markdown]
# <a href="https://colab.research.google.com/github/ishaan0506/phase-1-project-2405039371/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-bee98bb0-f09a-4e52-b687-e82b25f3b9ea" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-bee98bb0-f09a-4e52-b687-e82b25f3b9ea">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#import
import pandas as pd
df = pd.read_csv("Customer-Purchase-History.csv")
print(df.head())
# Out:
#   CustomerID  Product PurchaseDate  Quantity  UnitPrice    CustomerName  \
# 0      C5361    Phone   2024-03-05         8     618.83  Customer C5361
# 1      C6231   Laptop   2025-06-21         7     366.22  Customer C6231
# 2      C7704    Chair   2023-06-25         5     634.51  Customer C7704
# 3      C2923  Printer   2023-09-30         3     508.63  Customer C2923
# 4      C4847  Monitor   2023-04-03         4     452.06  Customer C4847
#
#    ProductCategory PaymentMethod  ReviewRating  TotalPrice
# 0  Office Supplies          Cash             1     4950.64
# 1      Electronics    Debit Card             3     2563.54
# 2  Office Supplies   Credit Card             4     3172.55
# 3  Office Supplies     Gift Card             1     1525.89
# 4      Electronics   Credit Card             2     1808.24

# %%
import matplotlib.pyplot as plt

best_selling.head(10).plot(kind="bar")

plt.title("Top 10 Best Selling Products")
plt.xlabel("Product")
plt.ylabel("Quantity Sold")

plt.show()

# %%
#Data cleaning
print(df.isnull().sum())

df.drop_duplicates(inplace=True)

print("Rows after cleaning:", len(df))
# Out:
# CustomerID         0
# Product            0
# PurchaseDate       0
# Quantity           0
# UnitPrice          0
# CustomerName       0
# ProductCategory    0
# PaymentMethod      0
# ReviewRating       0
# TotalPrice         0
# dtype: int64
# Rows after cleaning: 1800

# %%
#Best Selling product
best_selling = (
    df.groupby("Product")["Quantity"]
    .sum()
    .sort_values(ascending=False)
)

print(best_selling)
print(best_selling.head())
# Out:
# Product
# Tablet     1316
# Laptop     1231
# Monitor    1180
# Desk       1156
# Chair      1147
# Phone      1117
# Printer    1113
# Name: Quantity, dtype: int64
# Product
# Tablet     1316
# Laptop     1231
# Monitor    1180
# Desk       1156
# Chair      1147
# Name: Quantity, dtype: int64

# %%
#Revenue analysis
print("Total Revenue:", df["TotalPrice"].sum())

print("Average Revenue:", df["TotalPrice"].mean())

print("Maximum Sale:", df["TotalPrice"].max())

print("Minimum Sale:", df["TotalPrice"].min())
# Out:
# Total Revenue: 3266656.8
# Average Revenue: 1814.8093333333331
# Maximum Sale: 6389.12
# Minimum Sale: 6.06

# %%
#GroupBy Concept
df.groupby("Product")["Quantity"].sum()
# Out:
# Product
# Chair      1147
# Desk       1156
# Laptop     1231
# Monitor    1180
# Phone      1117
# Printer    1113
# Tablet     1316
# Name: Quantity, dtype: int64
